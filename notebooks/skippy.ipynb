# %%
import numpy as np
import src as qarl

# %%
generator = qarl.generator.gaussian(mean=5)
env = qarl.environment.GeneratorEnvironment(generator)
ag = qarl.agent.Agent(
    acceleration=np.ones(1) * 1.7897121877252560,
    braking=np.ones(1) * -0.0974316650691893,
)
g = qarl.game.Game(ag, env)

# %%
g.play_game()
g.show_stats()
